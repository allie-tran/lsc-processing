# %%
import bamboolib as bam
import pandas as pd

# %%
df = pd.read_csv(r'/home/tlduyen/LSC22/process/VAISL/files/pure_semantic_stops.csv', sep=',', decimal='.')

# %%
df
# Out:
#      Unnamed: 0   stop                checkin categories movement parent  \
# 0             0   True                   HOME        NaN      NaN    NaN
# 1             1  False                    NaN        NaN      Car    NaN
# 2             2   True  Charm Hand & Foot Spa        NaN      NaN    NaN
# 3             3  False                    NaN        NaN      Car    NaN
# 4             4   True          Unknown Place        NaN      NaN    NaN
# ..          ...    ...                    ...        ...      ...    ...
# 607         607   True  Charm Hand & Foot Spa        NaN      NaN    NaN
# 608         608  False                    NaN        NaN      Car    NaN
# 609         609   True          Unknown Place        NaN      NaN    NaN
# 610         610  False                    NaN        NaN      Car    NaN
# 611         611   True                   HOME        NaN      NaN    NaN
#
#      in_checkin original_name        lat       lon  ...  \
# ...

# %%
df2 = pd.read_csv(r'/home/tlduyen/LSC22/process/VAISL/files/agg_pure_stops.csv', sep=',', decimal='.')

# %%
df2 = df2.loc[df2["stop"] == False]
df2 = df2.reset_index()
df2
# Out:
#      index  Unnamed: 0  new_name   stop          checkin        lat       lon  \
# 0        1           1         2  False              Car  53.388425 -6.146717
# 1        3           3         4  False              Car  53.383899 -6.169577
# 2        5           5         6  False              Car  53.354467 -6.248757
# 3        7           7         8  False              Car  53.342912 -6.261475
# 4        9           9        10  False  Walking Outside  53.342248 -6.260186
# ..     ...         ...       ...    ...              ...        ...       ...
# 199    485         485       486  False              Car  53.389804 -6.156602
# 200    487         487       488  False              Car  53.388885 -6.203637
# 201    490         490       491  False              Car  53.380671 -6.216843
# 202    492         492       493  False              Car  53.389265 -6.155791
# 203    494         494       495  False              Car  53.389516 -6.165303
#
# ...

# %%
sum(df2["last"] == df["last"])
# Out:
# 204
